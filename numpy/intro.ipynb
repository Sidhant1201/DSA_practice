# %%
import numpy as np

# %%
l = [1, 2, 4]

# %%
np_l = np.array(l)

# %%
np_l * 2.5
# Out:
# array([ 2.5,  5. , 10. ])

# %%
l1 = [1, 2, 3,5 ,6]
l2 = [5, 1, 7, 9]

# %%
npl1= np.array(l1)

# %%
npl1.size
# Out:
# 5

# %%
type(npl1)
# Out:
# numpy.ndarray

# %%
npl1[npl1 < 5]
# Out:
# array([1, 2, 3])

# %%
np1
# Out:
#   Cell In[23], line 1
#     npl1.all(> 3)
#              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

df = pd.Data
